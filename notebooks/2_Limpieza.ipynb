# %% [markdown]
# ## Notebook 2: Limpieza
# En este notebook realizaremos las siguientes operaciones:
# 1. Buscar duplicados y quitar columnas innecesarias para el análisis.
# 2. Analizar recuentos de valores y valores únicos en columnas categóricas.
# 3. Rellenar valores nulos (NaNs).
# 4. Corregir tipos de datos: objects, floats, ints.
# 5. Tratar formatos de fecha.

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append("../")
from src import soporte_limpieza as sl
from src import soporte_variables as sv

pd.set_option('display.max_columns', None)

# %%
# Importo un único dataframe que se ha unido en el notebook "Exploración", que contiene la información de los 9 años de análisis.

df = pd.read_csv("../datos/brasil_completo.csv", parse_dates= ["fecha_registro"])

# %%
df.columns
# Out:
# Index(['codigo_organo_superior', 'nombre_organo_superior', 'codigo_organo',
#        'nombre_organo', 'codigo_unidad_gestora', 'nombre_unidad_gestora',
#        'categoria_economica', 'origen_ingreso', 'tipo_ingreso', 'detalle',
#        'valor_previsto_actualizado', 'valor_registrado', 'valor_ejecutado',
#        'porcentaje_ejecutado', 'fecha_registro', 'ano_ejercicio'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['codigo_organo_superior', 'nombre_organo_superior', 'codigo_organo',
#        'nombre_organo', 'codigo_unidad_gestora', 'nombre_unidad_gestora',
#        'categoria_economica', 'origen_ingreso', 'tipo_ingreso', 'detalle',
#        'valor_previsto_actualizado', 'valor_registrado', 'valor_ejecutado',
#        'porcentaje_ejecutado', 'fecha_registro', 'ano_ejercicio'],
#       dtype='object')

# %%
# Como se puede observar en este print, tenemos un total de 705455 registros nulos en todo el DF. El primer paso será reducirlos, tratándolos de forma particular según su tipo.

df.isna().sum()
# Out:
# codigo_organo_superior         30359
# nombre_organo_superior        359206
# codigo_organo                  25117
# nombre_organo                  34887
# codigo_unidad_gestora          33581
# nombre_unidad_gestora          19481
# categoria_economica            18978
# origen_ingreso                 38418
# tipo_ingreso                   31927
# detalle                        29337
# valor_previsto_actualizado     51315
# valor_registrado               26419
# valor_ejecutado                39465
# porcentaje_ejecutado           24134
# fecha_registro                 23831
# ano_ejercicio                      0
# dtype: int64

# %%
df.head(1)
# Out:
#    codigo_organo_superior nombre_organo_superior  codigo_organo  \
# 0                 63000.0                    NaN        63000.0
#
#                                        nombre_organo  codigo_unidad_gestora  \
# 0  Advocacia-Geral da União - Unidades com víncul...               110060.0
#
#                            nombre_unidad_gestora categoria_economica  \
# 0  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
#
#               origen_ingreso                                   tipo_ingreso  \
# 0  Outras Receitas Correntes  Bens, Direitos e Valores Incorporados ao Patr
#
#                                          detalle valor_previsto_actualizado  \
# 0  REC.DIVIDA ATIVA NAO TRIBUTARIA DE OUTRAS REC                       0,00
#
#   valor_registrado valor_ejecutado porcentaje_ejecutado       fecha_registro  \
# 0             0,00         1297,13                 0,00  2013-12-31 00:00:00
#
#    ano_ejercicio
# 0           2013

# %%
# Compruebo integridad del DF. Se mantiene el concatenado realizado en el notebook de Exploración.
df.shape
# Out:
# (1026299, 16)

# %%
# Empezaremos por cambiar el formato de las columnas que deberían ser numéricas, pero que actualmente son objetos:
# valor_previsto_actualizado
# valor_registrado
# valor_ejecutado
# porcentaje_ejecutado

# Por otro lado, aunque hayamos utilizado el parámetro parse_dates para importar el DF, en ocasiones podría no transformar la fecha, así que aplicaremos una función a la columna "fecha_registro" para corregirlo.

df.dtypes
# Out:
# codigo_organo_superior        float64
# nombre_organo_superior         object
# codigo_organo                 float64
# nombre_organo                  object
# codigo_unidad_gestora         float64
# nombre_unidad_gestora          object
# categoria_economica            object
# origen_ingreso                 object
# tipo_ingreso                   object
# detalle                        object
# valor_previsto_actualizado     object
# valor_registrado               object
# valor_ejecutado                object
# porcentaje_ejecutado           object
# fecha_registro                 object
# ano_ejercicio                   int64
# dtype: object

# %%
# Con describe, podemos confirmar que los valores monetarios, que deberían ser numéricos, no se corresponden con ese tipo de dato.

df.describe()
# Out:
#        codigo_organo_superior  codigo_organo  codigo_unidad_gestora  \
# count           995940.000000   1.001182e+06          992718.000000
# mean             32053.240155   3.143803e+04          231293.255710
# std              10614.740359   1.038598e+04          144174.177831
# min              20000.000000   2.010100e+04          110005.000000
# 25%              25000.000000   2.520100e+04          154003.000000
# 50%              26000.000000   2.629800e+04          170013.000000
# 75%              39000.000000   3.600000e+04          250088.000000
# max              81000.000000   9.121400e+04          913001.000000
#
#        ano_ejercicio
# count   1.026299e+06
# mean    2.018226e+03
# std     1.737966e+00
# min     2.013000e+03
# 25%     2.017000e+03
# 50%     2.018000e+03
# 75%     2.020000e+03
# max     2.021000e+03

# %%
# Utilizaremos en este notebook las funciones en el archivo de sorporte ubicado en ""../src/soporte_limpieza.py"

sl.valores_numeros(df, "valor_previsto_actualizado")
sl.valores_numeros(df, "valor_registrado")
sl.valores_numeros(df, "valor_ejecutado")
sl.valores_numeros(df, "porcentaje_ejecutado")

sl.conversion_fecha(df, "fecha_registro")

# Y comprobamos que se han ejecutado correctamente.
df.dtypes
# Out:
# codigo_organo_superior               float64
# nombre_organo_superior                object
# codigo_organo                        float64
# nombre_organo                         object
# codigo_unidad_gestora                float64
# nombre_unidad_gestora                 object
# categoria_economica                   object
# origen_ingreso                        object
# tipo_ingreso                          object
# detalle                               object
# valor_previsto_actualizado           float64
# valor_registrado                     float64
# valor_ejecutado                      float64
# porcentaje_ejecutado                 float64
# fecha_registro                datetime64[ns]
# ano_ejercicio                          int64
# dtype: object

# %%
# Analizando el DF, hay columnas que guardan relación entre sí, pero que, en algunos casos, tienen datos nulos en una u otra. Ocurre en los casos de:

# codigo_organo_superior y nombre_organo_superior
# codigo_organo y nombre_organo
# codigo_unidad_gestora y nombre_unidad gestora

df.head(1)
# Out:
#    codigo_organo_superior nombre_organo_superior  codigo_organo  \
# 0                 63000.0                    NaN        63000.0
#
#                                        nombre_organo  codigo_unidad_gestora  \
# 0  Advocacia-Geral da União - Unidades com víncul...               110060.0
#
#                            nombre_unidad_gestora categoria_economica  \
# 0  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
#
#               origen_ingreso                                   tipo_ingreso  \
# 0  Outras Receitas Correntes  Bens, Direitos e Valores Incorporados ao Patr
#
#                                          detalle  valor_previsto_actualizado  \
# 0  REC.DIVIDA ATIVA NAO TRIBUTARIA DE OUTRAS REC                         0.0
#
#    valor_registrado  valor_ejecutado  porcentaje_ejecutado fecha_registro  \
# 0               0.0          1297.13                   0.0     2013-12-31
#
#    ano_ejercicio
# 0           2013

# %%
# Podemos utilizar funciones para eliminar todos estos valores nulos.
# Hemos relacionado el nombre de cada entidad con su código creando diccionarios en el notebook "Diccionarios", y los resultados están almacenados en "../src/support_variables".

# Los parámetros que recibe la función rellenar_codigos_nombres función son 4:
# (dataframe, columna codigo, columna nombre, diccionario).DS_Store

# Con esta función, rellenaremos la columna código con los nombres, dado que son más fáciles de interpretar para el análisis. El último paso que ejecuta es eliminar las columnas de nombres, por cuanto serían redudantes.

sl.rellenar_codigos_nombres(df,"codigo_organo_superior","nombre_organo_superior",sv.dicc_organo_superior)
sl.rellenar_codigos_nombres(df,"codigo_organo","nombre_organo",sv.dicc_organo)
sl.rellenar_codigos_nombres(df,"codigo_unidad_gestora","nombre_unidad_gestora",sv.dicc_unidad_gestora)
# Out:
#            codigo_organo_superior  \
# 0        Advocacia-Geral da União
# 1        Advocacia-Geral da União
# 2        Advocacia-Geral da União
# 3        Advocacia-Geral da União
# 4        Advocacia-Geral da União
# ...                           ...
# 1026294  Presidência da República
# 1026295  Presidência da República
# 1026296  Presidência da República
# 1026297  Presidência da República
# 1026298  Presidência da República
#
#                                              codigo_organo  \
# 0        Advocacia-Geral da União - Unidades com víncul...
# 1        Advocacia-Geral da União - Unidades com víncul...
# 2        Advocacia-Geral da União - Unidades com víncul...
# 3        Advocacia-Geral da União - Unidades com víncul...
# 4        Advocacia-Geral da União - Unidades com víncul...
# ...                                                    ...
# 1026294     Instituto Nacional de Tecnologia da Informação
# 1026295     Instituto Nacional de Tecnologia da Informação
# 1026296     Instituto Nacional de Tecnologia da Informação
# 1026297     Instituto Nacional de Tecnologia da Informação
# 1026298     Instituto Nacional de Tecnologia da Informação
#
#                                  codigo_unidad_gestora  categoria_economica  \
# 0        COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU   Receitas Correntes
# 1        COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU   Receitas Correntes
# 2        COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU   Receitas Correntes
# 3        COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU   Receitas Correntes
# 4        COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU   Receitas Correntes
# ...                                                ...                  ...
# 1026294  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI  Receitas de Capital
# 1026295  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI   Receitas Correntes
# 1026296  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI   Receitas Correntes
# 1026297  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI   Receitas Correntes
# 1026298  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI   Receitas Correntes
#
#                     origen_ingreso  \
# 0        Outras Receitas Correntes
# 1        Outras Receitas Correntes
# 2        Outras Receitas Correntes
# 3        Outras Receitas Correntes
# 4        Outras Receitas Correntes
# ...                            ...
# 1026294       Operações de Crédito
# 1026295        Receita de Serviços
# 1026296        Receita de Serviços
# 1026297        Receita de Serviços
# 1026298        Receita de Serviços
#
#                                           tipo_ingreso  \
# 0        Bens, Direitos e Valores Incorporados ao Patr
# 1          Indenizações, restituições e ressarcimentos
# 2        Multas administrativas, contratuais e judicia
# 3        Bens, Direitos e Valores Incorporados ao Patr
# 4          Indenizações, restituições e ressarcimentos
# ...                                                ...
# 1026294         Operações de crédito - mercado interno
# 1026295   Serviços Administrativos e Comerciais Gerais
# 1026296   Serviços Administrativos e Comerciais Gerais
# 1026297   Serviços Administrativos e Comerciais Gerais
# 1026298   Serviços Administrativos e Comerciais Gerais
#
#                                                detalle  \
# 0        REC.DIVIDA ATIVA NAO TRIBUTARIA DE OUTRAS REC
# 1         RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES
# 2                        OUTRAS MULTAS E JUROS DE MORA
# 3            REC.DIV.ATIVA POR INFRAÇÃO ADMINISTRATIVA
# 4                                  OUTRAS RESTITUICOES
# ...                                                ...
# 1026294   TITULOS DE RESPONS.TES.NAC.-MERC.INT.-PRINC.
# 1026295   SERV.DE REGIST.,CERTIF.E FISCALIZ.-PRINCIPAL
# 1026296   SERV.DE REGIST.,CERTIF.E FISCALIZ.-PRINCIPAL
# 1026297   SERV.DE REGIST.,CERTIF.E FISCALIZ.-PRINCIPAL
# 1026298   SERV.DE REGIST.,CERTIF.E FISCALIZ.-PRINCIPAL
#
#          valor_previsto_actualizado  valor_registrado  valor_ejecutado  \
# 0                               0.0               0.0          1297.13
# 1                               0.0               0.0      26666621.42
# 2                               0.0               0.0        301251.13
# 3                               0.0               0.0          1855.58
# 4                               0.0               0.0         52140.68
# ...                             ...               ...              ...
# 1026294                  16940891.0               0.0             0.00
# 1026295                         0.0               0.0              NaN
# 1026296                    200000.0               0.0             0.00
# 1026297                         0.0               0.0       1000000.00
# 1026298                         0.0               0.0       1000000.00
#
#          porcentaje_ejecutado fecha_registro  ano_ejercicio
# 0                         0.0     2013-12-31           2013
# 1                         0.0     2013-12-31           2013
# 2                         0.0     2013-12-31           2013
# 3                         0.0     2013-12-31           2013
# 4                         0.0     2013-12-31           2013
# ...                       ...            ...            ...
# 1026294                   0.0     2021-04-23           2021
# 1026295                   0.0     2021-11-22           2021
# 1026296                   0.0     2021-04-23           2021
# 1026297                   NaN     2021-05-10           2021
# 1026298                   0.0     2021-03-23           2021
#
# [1026299 rows x 13 columns]

# %%
# Ahora que tenemos las columnas de código de entidades completas, las podemos renombrar para que sean fieles a su contenido.

df.rename(columns={"codigo_organo_superior":"organo_superior"}, inplace=True)
df.rename(columns={"codigo_organo":"organo"}, inplace=True)
df.rename(columns={"codigo_unidad_gestora":"unidad_gestora"}, inplace=True)

# Comprobamos los cambios, nos hemos quedado con un DF mucho más legible y completo.
df.head(1)
# Out:
#             organo_superior  \
# 0  Advocacia-Geral da União
#
#                                               organo  \
# 0  Advocacia-Geral da União - Unidades com víncul...
#
#                                   unidad_gestora categoria_economica  \
# 0  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
#
#               origen_ingreso                                   tipo_ingreso  \
# 0  Outras Receitas Correntes  Bens, Direitos e Valores Incorporados ao Patr
#
#                                          detalle  valor_previsto_actualizado  \
# 0  REC.DIVIDA ATIVA NAO TRIBUTARIA DE OUTRAS REC                         0.0
#
#    valor_registrado  valor_ejecutado  porcentaje_ejecutado fecha_registro  \
# 0               0.0          1297.13                   0.0     2013-12-31
#
#    ano_ejercicio
# 0           2013

# %%
# Compruebo nuevamente que se mantenga la integridad del DF. El número de columnas se ha reducido en 3 dado que se han eliminado las columnas de código, pero las filas se mantienen.

df.shape
# Out:
# (1026299, 13)

# %%
# Limpiaremos ahora las columnas categoria_economica, origen_ingreso y tipo_ingreso.

df["categoria_economica"].unique()
# Out:
# array(['Receitas Correntes', 'Receitas de Capital', nan,
#        'Receitas Correntes - intra-orçamentárias', 'Sem informação',
#        'Receitas de Capital - intra-orçamentárias'], dtype=object)

# %%
df["origen_ingreso"].unique()
# Out:
# array(['Outras Receitas Correntes', 'Receita de Serviços',
#        'Transferências de Capital', 'Alienação de Bens',
#        'Receita Agropecuária', 'Transferências Correntes',
#        'Receita Patrimonial', 'Operações de Crédito',
#        'Impostos, Taxas e Contribuições de Melhoria', nan,
#        'Amortizações de Empréstimos', 'Contribuições',
#        'Receita Industrial', 'Outras Receitas de Capital',
#        'Receitas Correntes - a classificar', 'Sem informação'],
#       dtype=object)

# %%
df["tipo_ingreso"].unique()
# Out:
# array(['Bens, Direitos e Valores Incorporados ao Patr',
#        'Indenizações, restituições e ressarcimentos',
#        'Multas administrativas, contratuais e judicia',
#        'Demais receitas correntes', 'Receita de Serviços',
#        'Transferências de Instituições Privadas',
#        'Alienação de bens móveis',
#        'Receita da produção animal e derivados',
#        'Transferências dos Municípios e de suas Entid',
#        'Alienação de bens imóveis', 'Transferências de Pessoas Físicas',
#        'Valores Mobiliários',
#        'Exploração do patrimônio imobiliário do Estad',
#        'Operações de crédito - mercado interno', 'Taxas', nan,
#        'Delegação de Serviços Públicos Mediante Conce',
#        'Outras receitas agropecuárias', 'Amortizações de Empréstimos',
#        'Contribuições econômicas', 'Transferências de Convênios',
#        'Indenizações e restituições',
#        'Receitas da indústria de transformação', 'Contribuições sociais',
#        'Receita dívida ativa alienação de estoques de',
#        'Receita da produção vegetal',
#        'Receita dívida ativa proveniente de amortizaç',
#        'Exploração de recursos naturais',
#        'Receitas Correntes - a classificar',
#        'Receita de concessões e permissões',
#        'Demais receitas patrimoniais', 'Cessão de direitos',
#        'Transferências de Outras Instituições Pública',
#        'Operações de crédito - mercado externo', 'Impostos',
#        'Resultado do Banco Central do Brasil',
#        'Receitas decorrentes de aportes periódicos pa', 'Sem informação',
#        'Receitas de valores mobiliários',
#        'Receitas decorrentes de compensações ao Regim',
#        'Receita títulos do tesouro nacional resgatado',
#        'Remuneração das Disponibilidades do Tesouro N', 'Outras receitas',
#        'Transferências do Exterior',
#        'Transferências dos Estados e do Distrito Fede',
#        'Integralização do capital social', 'Receita da dívida ativa',
#        'Serviços Administrativos e Comerciais Gerais', 'Outros serviços',
#        'Receita Agropecuária', 'Transferências Correntes',
#        'Transferências da União e de suas Entidades',
#        'Receita Industrial', 'Serviços e Atividades Financeiras',
#        'Transferências de Capital',
#        'Serviços e Atividades Referentes à Saúde',
#        'Serviços e Atividades Referentes à Navegação ',
#        'Remuneração das Disponibilidades do Tesouro',
#        'Contribuições para Entidades Privadas de Serv',
#        'Alienação de bens intangíveis', 'Resgate de Títulos do Tesouro',
#        'Exploração do patrimônio intangível',
#        'Transferências Provenientes de Depósito Não I',
#        'Demais receitas de capital'], dtype=object)

# %%
# Llamos a función para sustituir nulos con "Desconocido":

sl.nulos_categoricos(df,"categoria_economica")
sl.nulos_categoricos(df,"origen_ingreso")
sl.nulos_categoricos(df,"tipo_ingreso")

# Y para el resto de datos, usaremos un diccionario para traducir los datos y unificar transformar las entradas "Sem informaćão" a "Desconocido", como los nulos.

sl.traducir_dicc(df,"categoria_economica",sv.dicc_cat_economica)
sl.traducir_dicc(df,"origen_ingreso",sv.dicc_tipo_ingreso)
sl.traducir_dicc(df,"tipo_ingreso",sv.dicc_tipo_ingreso)
# Out:
#                   organo_superior  \
# 0        Advocacia-Geral da União
# 1        Advocacia-Geral da União
# 2        Advocacia-Geral da União
# 3        Advocacia-Geral da União
# 4        Advocacia-Geral da União
# ...                           ...
# 1026294  Presidência da República
# 1026295  Presidência da República
# 1026296  Presidência da República
# 1026297  Presidência da República
# 1026298  Presidência da República
#
#                                                     organo  \
# 0        Advocacia-Geral da União - Unidades com víncul...
# 1        Advocacia-Geral da União - Unidades com víncul...
# 2        Advocacia-Geral da União - Unidades com víncul...
# 3        Advocacia-Geral da União - Unidades com víncul...
# 4        Advocacia-Geral da União - Unidades com víncul...
# ...                                                    ...
# 1026294     Instituto Nacional de Tecnologia da Informação
# 1026295     Instituto Nacional de Tecnologia da Informação
# 1026296     Instituto Nacional de Tecnologia da Informação
# 1026297     Instituto Nacional de Tecnologia da Informação
# 1026298     Instituto Nacional de Tecnologia da Informação
#
#                                         unidad_gestora  categoria_economica  \
# 0        COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# 1        COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# 2        COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# 3        COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# 4        COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# ...                                                ...                  ...
# 1026294  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI  Ingresos de Capital
# 1026295  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI  Ingresos Corrientes
# 1026296  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI  Ingresos Corrientes
# 1026297  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI  Ingresos Corrientes
# 1026298  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI  Ingresos Corrientes
#
#                     origen_ingreso  \
# 0        Outras Receitas Correntes
# 1        Outras Receitas Correntes
# 2        Outras Receitas Correntes
# 3        Outras Receitas Correntes
# 4        Outras Receitas Correntes
# ...                            ...
# 1026294       Operações de Crédito
# 1026295     Ingresos por Servicios
# 1026296     Ingresos por Servicios
# 1026297     Ingresos por Servicios
# 1026298     Ingresos por Servicios
#
#                                               tipo_ingreso  \
# 0        Bienes, Derechos y Valores Incorporados al Pat...
# 1               Indemnizaciones, devoluciones y reembolsos
# 2        Multas administrativas, contractuales y judici...
# 3        Bienes, Derechos y Valores Incorporados al Pat...
# 4               Indemnizaciones, devoluciones y reembolsos
# ...                                                    ...
# 1026294           Operaciones de crédito - mercado interno
# 1026295  Servicios Administrativos y Comerciales Generales
# 1026296  Servicios Administrativos y Comerciales Generales
# 1026297  Servicios Administrativos y Comerciales Generales
# 1026298  Servicios Administrativos y Comerciales Generales
#
#                                                detalle  \
# 0        REC.DIVIDA ATIVA NAO TRIBUTARIA DE OUTRAS REC
# 1         RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES
# 2                        OUTRAS MULTAS E JUROS DE MORA
# 3            REC.DIV.ATIVA POR INFRAÇÃO ADMINISTRATIVA
# 4                                  OUTRAS RESTITUICOES
# ...                                                ...
# 1026294   TITULOS DE RESPONS.TES.NAC.-MERC.INT.-PRINC.
# 1026295   SERV.DE REGIST.,CERTIF.E FISCALIZ.-PRINCIPAL
# 1026296   SERV.DE REGIST.,CERTIF.E FISCALIZ.-PRINCIPAL
# 1026297   SERV.DE REGIST.,CERTIF.E FISCALIZ.-PRINCIPAL
# 1026298   SERV.DE REGIST.,CERTIF.E FISCALIZ.-PRINCIPAL
#
#          valor_previsto_actualizado  valor_registrado  valor_ejecutado  \
# 0                               0.0               0.0          1297.13
# 1                               0.0               0.0      26666621.42
# 2                               0.0               0.0        301251.13
# 3                               0.0               0.0          1855.58
# 4                               0.0               0.0         52140.68
# ...                             ...               ...              ...
# 1026294                  16940891.0               0.0             0.00
# 1026295                         0.0               0.0              NaN
# 1026296                    200000.0               0.0             0.00
# 1026297                         0.0               0.0       1000000.00
# 1026298                         0.0               0.0       1000000.00
#
#          porcentaje_ejecutado fecha_registro  ano_ejercicio
# 0                         0.0     2013-12-31           2013
# 1                         0.0     2013-12-31           2013
# 2                         0.0     2013-12-31           2013
# 3                         0.0     2013-12-31           2013
# 4                         0.0     2013-12-31           2013
# ...                       ...            ...            ...
# 1026294                   0.0     2021-04-23           2021
# 1026295                   0.0     2021-11-22           2021
# 1026296                   0.0     2021-04-23           2021
# 1026297                   NaN     2021-05-10           2021
# 1026298                   0.0     2021-03-23           2021
#
# [1026299 rows x 13 columns]

# %%
# Comprobamos que:
# 1. no tenemos nulos que,
# 2. para todos los datos desconocidos, ahora tenemos una única etiqueta y,
# 3. los valores del diccionario se han sustituido para mostrar las categorías en español.

df["categoria_economica"].unique()
# Out:
# array(['Ingresos Corrientes', 'Ingresos de Capital', 'Desconocido',
#        'Ingresos Corrientes - intra-presupuestarios',
#        'Ingresos de Capital - intra-presupuestarios'], dtype=object)

# %%
# Corresponde ahora decidir cómo tratar los valores nulos en las columnas numéricas. En el caso del porcentaje_ejecutado, sabemos que es el producto de la divisón entre el valor_ejecutado/valor_previsto_actualizado, con lo cual, una vez limpias las otras columnas, podemos recalcularlo y reducir al mínimo el número de filas perdidas.

# %%
df.sample(5)[["valor_previsto_actualizado","valor_registrado","valor_ejecutado","porcentaje_ejecutado"]]
# Out:
#         valor_previsto_actualizado  valor_registrado  valor_ejecutado  \
# 256741                         0.0               0.0         75000.00
# 656819                         0.0               0.0          8489.12
# 260577                         0.0               0.0          3687.63
# 290258                         0.0               0.0          3899.31
# 926713                         0.0               0.0           624.60
#
#         porcentaje_ejecutado
# 256741                   0.0
# 656819                   0.0
# 260577                   0.0
# 290258                   0.0
# 926713                   0.0

# %%
df[["valor_previsto_actualizado","valor_registrado","valor_ejecutado","porcentaje_ejecutado"]].isna().sum()
# Out:
# valor_previsto_actualizado    51315
# valor_registrado              26419
# valor_ejecutado               39465
# porcentaje_ejecutado          24134
# dtype: int64

# %%
# En total, tenemos en las columnas valor_previsto_actualizado, valor_registrado y valor_ejecutado un total de 117199 nulos, que se corresponde con un 11% de las filas totales. Dado que, no nos aportan valor, procederemos a eliminarlos para el análisis.

# Rellenarlos con 0 no sería correcto porque, distorsionaría los valores estadísticos. Además, no tenemos certeza sobre si, esa infomación simplemente no ha sido incluida en los CSV entregados por el gobierno de Brasil.

# Otra opción para rellenar numérico nulos es utilizar el -999, pero acabaríamos muchos valores atípicos y distorsionados.

# %%
df.shape
# Out:
# (1026299, 13)

# %%
# Procedemos a eliminar los nulos del resto de columnas numéricas.
df.dropna(subset=["valor_previsto_actualizado"], inplace=True)
df.dropna(subset=["valor_registrado"], inplace=True)
df.dropna(subset=["valor_ejecutado"], inplace=True)

# %%
df.shape
# Out:
# (913459, 13)

# %%
# Recalculamos la columna porcentaje_ejecutado para asegurarnos de que tenemos los valores deseados.
df["porcentaje_ejecutado"] = df["valor_ejecutado"] / df["valor_previsto_actualizado"] * 100
df["porcentaje_ejecutado"] = df["porcentaje_ejecutado"].replace({np.inf: 0})

# %%
# Comprobamos que hemos eliminado los nulos de las columnas numéricas
df.dropna(subset=["porcentaje_ejecutado"], inplace=True)
df[["valor_previsto_actualizado","valor_registrado","valor_ejecutado","porcentaje_ejecutado"]].isna().sum()
# Out:
# valor_previsto_actualizado    0
# valor_registrado              0
# valor_ejecutado               0
# porcentaje_ejecutado          0
# dtype: int64

# %%
df.head(5)
# Out:
#             organo_superior  \
# 0  Advocacia-Geral da União
# 1  Advocacia-Geral da União
# 2  Advocacia-Geral da União
# 3  Advocacia-Geral da União
# 4  Advocacia-Geral da União
#
#                                               organo  \
# 0  Advocacia-Geral da União - Unidades com víncul...
# 1  Advocacia-Geral da União - Unidades com víncul...
# 2  Advocacia-Geral da União - Unidades com víncul...
# 3  Advocacia-Geral da União - Unidades com víncul...
# 4  Advocacia-Geral da União - Unidades com víncul...
#
#                                   unidad_gestora  categoria_economica  \
# 0  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# 1  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# 2  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# 3  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# 4  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
#
#               origen_ingreso  \
# 0  Outras Receitas Correntes
# 1  Outras Receitas Correntes
# 2  Outras Receitas Correntes
# 3  Outras Receitas Correntes
# 4  Outras Receitas Correntes
#
#                                         tipo_ingreso  \
# 0  Bienes, Derechos y Valores Incorporados al Pat...
# 1         Indemnizaciones, devoluciones y reembolsos
# 2  Multas administrativas, contractuales y judici...
# 3  Bienes, Derechos y Valores Incorporados al Pat...
# 4         Indemnizaciones, devoluciones y reembolsos
#
#                                          detalle  valor_previsto_actualizado  \
# 0  REC.DIVIDA ATIVA NAO TRIBUTARIA DE OUTRAS REC                         0.0
# 1   RECUPERACAO DE DESPESAS DE EXERC. ANTERIORES                         0.0
# 2                  OUTRAS MULTAS E JUROS DE MORA                         0.0
# 3      REC.DIV.ATIVA POR INFRAÇÃO ADMINISTRATIVA                         0.0
# 4                            OUTRAS RESTITUICOES                         0.0
#
#    valor_registrado  valor_ejecutado  porcentaje_ejecutado fecha_registro  \
# 0               0.0          1297.13                   0.0     2013-12-31
# 1               0.0      26666621.42                   0.0     2013-12-31
# 2               0.0        301251.13                   0.0     2013-12-31
# 3               0.0          1855.58                   0.0     2013-12-31
# 4               0.0         52140.68                   0.0     2013-12-31
#
#    ano_ejercicio
# 0           2013
# 1           2013
# 2           2013
# 3           2013
# 4           2013

# %%
# Eliminaremos la columna detalle, por cuanto contiene información demasiado específica, que no será de utilidad para el análisis.

df = df.drop(columns=["detalle"])

# %%
df.isna().sum()

# En este print, vemos que hemos reducido drásticamente la cantidad de registros nulos, estando la mayoría en la columna fecha, que podríamos eliminar, dado que no es de mayor interés para nuestro análisis, pudiendo utilizar el "ano_ejercicio" como serie temporal. 
# Podríamos rellenarla sólamente con años, pero no añadiría valor al análisis.
# Out:
# organo_superior                 9294
# organo                           797
# unidad_gestora                   551
# categoria_economica                0
# origen_ingreso                     0
# tipo_ingreso                       0
# valor_previsto_actualizado         0
# valor_registrado                   0
# valor_ejecutado                    0
# porcentaje_ejecutado               0
# fecha_registro                343436
# ano_ejercicio                      0
# dtype: int64

# %%
# Procedemos a eliminar la columna fecha.
df = df.drop(columns=["fecha_registro"])

# %%
# Hemos pasado de tener más de 700 mil registros nulos en nuestro DF a poco menos de 11 mil, en total 10642.
df.isna().sum()
# Out:
# organo_superior               9294
# organo                         797
# unidad_gestora                 551
# categoria_economica              0
# origen_ingreso                   0
# tipo_ingreso                     0
# valor_previsto_actualizado       0
# valor_registrado                 0
# valor_ejecutado                  0
# porcentaje_ejecutado             0
# ano_ejercicio                    0
# dtype: int64

# %%
# Rellenamos nulos en las 3 primeras columnas con "Desconocido", con ayuda de una función.

sl.nulos_categoricos(df, "organo_superior")
sl.nulos_categoricos(df, "organo")
sl.nulos_categoricos(df, "unidad_gestora")
# Out:
#                   organo_superior  \
# 0        Advocacia-Geral da União
# 1        Advocacia-Geral da União
# 2        Advocacia-Geral da União
# 3        Advocacia-Geral da União
# 4        Advocacia-Geral da União
# ...                           ...
# 1026293  Presidência da República
# 1026294  Presidência da República
# 1026296  Presidência da República
# 1026297  Presidência da República
# 1026298  Presidência da República
#
#                                                     organo  \
# 0        Advocacia-Geral da União - Unidades com víncul...
# 1        Advocacia-Geral da União - Unidades com víncul...
# 2        Advocacia-Geral da União - Unidades com víncul...
# 3        Advocacia-Geral da União - Unidades com víncul...
# 4        Advocacia-Geral da União - Unidades com víncul...
# ...                                                    ...
# 1026293          Gabinete da Vice-Presidência da República
# 1026294     Instituto Nacional de Tecnologia da Informação
# 1026296     Instituto Nacional de Tecnologia da Informação
# 1026297     Instituto Nacional de Tecnologia da Informação
# 1026298     Instituto Nacional de Tecnologia da Informação
#
#                                         unidad_gestora  categoria_economica  \
# 0        COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# 1        COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# 2        COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# 3        COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# 4        COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# ...                                                ...                  ...
# 1026293      GABINETE DA VICE-PRESIDENCIA DA REPUBLICA  Ingresos de Capital
# 1026294  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI  Ingresos de Capital
# 1026296  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI  Ingresos Corrientes
# 1026297  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI  Ingresos Corrientes
# 1026298  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI  Ingresos Corrientes
#
#                     origen_ingreso  \
# 0        Outras Receitas Correntes
# 1        Outras Receitas Correntes
# 2        Outras Receitas Correntes
# 3        Outras Receitas Correntes
# 4        Outras Receitas Correntes
# ...                            ...
# 1026293       Operações de Crédito
# 1026294       Operações de Crédito
# 1026296     Ingresos por Servicios
# 1026297     Ingresos por Servicios
# 1026298     Ingresos por Servicios
#
#                                               tipo_ingreso  \
# 0        Bienes, Derechos y Valores Incorporados al Pat...
# 1               Indemnizaciones, devoluciones y reembolsos
# 2        Multas administrativas, contractuales y judici...
# 3        Bienes, Derechos y Valores Incorporados al Pat...
# 4               Indemnizaciones, devoluciones y reembolsos
# ...                                                    ...
# 1026293           Operaciones de crédito - mercado interno
# 1026294           Operaciones de crédito - mercado interno
# 1026296  Servicios Administrativos y Comerciales Generales
# 1026297  Servicios Administrativos y Comerciales Generales
# 1026298  Servicios Administrativos y Comerciales Generales
#
#          valor_previsto_actualizado  valor_registrado  valor_ejecutado  \
# 0                               0.0               0.0          1297.13
# 1                               0.0               0.0      26666621.42
# 2                               0.0               0.0        301251.13
# 3                               0.0               0.0          1855.58
# 4                               0.0               0.0         52140.68
# ...                             ...               ...              ...
# 1026293                  10247198.0               0.0             0.00
# 1026294                  16940891.0               0.0             0.00
# 1026296                    200000.0               0.0             0.00
# 1026297                         0.0               0.0       1000000.00
# 1026298                         0.0               0.0       1000000.00
#
#          porcentaje_ejecutado  ano_ejercicio
# 0                         0.0           2013
# 1                         0.0           2013
# 2                         0.0           2013
# 3                         0.0           2013
# 4                         0.0           2013
# ...                       ...            ...
# 1026293                   0.0           2021
# 1026294                   0.0           2021
# 1026296                   0.0           2021
# 1026297                   0.0           2021
# 1026298                   0.0           2021
#
# [903723 rows x 11 columns]

# %%
# Nos hemos quedado en cero nulos.
df.isna().sum()
# Out:
# organo_superior               0
# organo                        0
# unidad_gestora                0
# categoria_economica           0
# origen_ingreso                0
# tipo_ingreso                  0
# valor_previsto_actualizado    0
# valor_registrado              0
# valor_ejecutado               0
# porcentaje_ejecutado          0
# ano_ejercicio                 0
# dtype: int64

# %%
# Buscamos duplicados
df.duplicated().value_counts()
# Out:
# False    819626
# True      84097
# Name: count, dtype: int64

# %%
# Eliminmos los índices duplicados.
df.reset_index()
# Out:
#           index           organo_superior  \
# 0             0  Advocacia-Geral da União
# 1             1  Advocacia-Geral da União
# 2             2  Advocacia-Geral da União
# 3             3  Advocacia-Geral da União
# 4             4  Advocacia-Geral da União
# ...         ...                       ...
# 903718  1026293  Presidência da República
# 903719  1026294  Presidência da República
# 903720  1026296  Presidência da República
# 903721  1026297  Presidência da República
# 903722  1026298  Presidência da República
#
#                                                    organo  \
# 0       Advocacia-Geral da União - Unidades com víncul...
# 1       Advocacia-Geral da União - Unidades com víncul...
# 2       Advocacia-Geral da União - Unidades com víncul...
# 3       Advocacia-Geral da União - Unidades com víncul...
# 4       Advocacia-Geral da União - Unidades com víncul...
# ...                                                   ...
# 903718          Gabinete da Vice-Presidência da República
# 903719     Instituto Nacional de Tecnologia da Informação
# 903720     Instituto Nacional de Tecnologia da Informação
# 903721     Instituto Nacional de Tecnologia da Informação
# 903722     Instituto Nacional de Tecnologia da Informação
#
#                                        unidad_gestora  categoria_economica  \
# 0       COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# 1       COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# 2       COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# 3       COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# 4       COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
# ...                                               ...                  ...
# 903718      GABINETE DA VICE-PRESIDENCIA DA REPUBLICA  Ingresos de Capital
# 903719  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI  Ingresos de Capital
# 903720  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI  Ingresos Corrientes
# 903721  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI  Ingresos Corrientes
# 903722  INSTITUTO NAC.DE TECNOLOGIA DA INFORMACAO ITI  Ingresos Corrientes
#
#                    origen_ingreso  \
# 0       Outras Receitas Correntes
# 1       Outras Receitas Correntes
# 2       Outras Receitas Correntes
# 3       Outras Receitas Correntes
# 4       Outras Receitas Correntes
# ...                           ...
# 903718       Operações de Crédito
# 903719       Operações de Crédito
# 903720     Ingresos por Servicios
# 903721     Ingresos por Servicios
# 903722     Ingresos por Servicios
#
#                                              tipo_ingreso  \
# 0       Bienes, Derechos y Valores Incorporados al Pat...
# 1              Indemnizaciones, devoluciones y reembolsos
# 2       Multas administrativas, contractuales y judici...
# 3       Bienes, Derechos y Valores Incorporados al Pat...
# 4              Indemnizaciones, devoluciones y reembolsos
# ...                                                   ...
# 903718           Operaciones de crédito - mercado interno
# 903719           Operaciones de crédito - mercado interno
# 903720  Servicios Administrativos y Comerciales Generales
# 903721  Servicios Administrativos y Comerciales Generales
# 903722  Servicios Administrativos y Comerciales Generales
#
#         valor_previsto_actualizado  valor_registrado  valor_ejecutado  \
# 0                              0.0               0.0          1297.13
# 1                              0.0               0.0      26666621.42
# 2                              0.0               0.0        301251.13
# 3                              0.0               0.0          1855.58
# 4                              0.0               0.0         52140.68
# ...                            ...               ...              ...
# 903718                  10247198.0               0.0             0.00
# 903719                  16940891.0               0.0             0.00
# 903720                    200000.0               0.0             0.00
# 903721                         0.0               0.0       1000000.00
# 903722                         0.0               0.0       1000000.00
#
#         porcentaje_ejecutado  ano_ejercicio
# 0                        0.0           2013
# 1                        0.0           2013
# 2                        0.0           2013
# 3                        0.0           2013
# 4                        0.0           2013
# ...                      ...            ...
# 903718                   0.0           2021
# 903719                   0.0           2021
# 903720                   0.0           2021
# 903721                   0.0           2021
# 903722                   0.0           2021
#
# [903723 rows x 12 columns]

# %%
df.head(1)
# Out:
#             organo_superior  \
# 0  Advocacia-Geral da União
#
#                                               organo  \
# 0  Advocacia-Geral da União - Unidades com víncul...
#
#                                   unidad_gestora  categoria_economica  \
# 0  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Ingresos Corrientes
#
#               origen_ingreso  \
# 0  Outras Receitas Correntes
#
#                                         tipo_ingreso  \
# 0  Bienes, Derechos y Valores Incorporados al Pat...
#
#    valor_previsto_actualizado  valor_registrado  valor_ejecutado  \
# 0                         0.0               0.0          1297.13
#
#    porcentaje_ejecutado  ano_ejercicio
# 0                   0.0           2013

# %%
# Eliminaremos la nueva columa index, surgida del reset.
# df = df.drop(columns=["index"])

# %%
# Hacemos una comprobación final de los datos limpios de nuestro DF. Hemos perdido dos columna al eliminar "detalle" y "fecha_registro". Todo correcto.
df.shape
# Out:
# (903723, 11)

# %%
# Procedemos a almacenar en un nuevo archivo CSV, que servirá para el análisis y visualización.

df.to_csv("../datos/brasil_limpio.csv", index=False)

# %% [markdown]
# ### Resumen:
#
# En este notebook hemos:
# 1. Cambiado el tipo de dato de las columnas numéricas, de object a float.
#
# 2. Cambiado el formato de la fecha para que sea tratable por pandas con el método pd.todatetime.
#
# 3. Relacionando los códigos y los nombres de los órganos, completado la columna de códigos con los nombres para evitar nulos. Hemos reemplazado los códigos porque, para el análisis, es más sencillo trabajar con el nombre del ente y no un código poco interpretable.
#
# 4. Eliminado entonces la duplicidad en la columna "nombre" de los entes. Reducimos nuestro DF en 3 columnas, haciendolo más manejable.
#
# 5. Elimanado la columna detalle, por cuanto aporta información demasiado específica para nuestro análisis, así como fecha de registro, por contener demasiados nulos y ser innecesaria, pudiendo usar como serie temporal el año. En total, nos hemos quedado con 11 columnas.
#
# 6. Reemplazado los valores nulos y las etiquetas "sem informação" en las columnas categoria_economica, origen_ingreso y tipo_ingreso, quedándonos sin valores nulos.
#
# 7. Eliminado las filas con valores nulos en las columnas valor_actualizado, valor_registrado, valor_ejecutado y porcentaje_ejecutado. En términos porcentuales es una reducción del 9% de nuestro dataframe.
#
# 8. En total, reducido a cero los valores nulos del dataframe, sacrificando únicamente un 9% del total de filas.
#
# 9. Eliminado los índices duplicados.
#
# 10. Exportado un nuevo dataframe para realizar el análisis y visualización.
